# %%
# Import libraries
import pandas as pd

# %%
# Save extracted CSV files to Dataframes
forces_df = pd.read_csv('../data/extract/raw_data_part_0.csv')
dates_df = pd.read_csv('../data/extract/raw_data_part_1.csv')
crime_data_df = pd.read_csv('../data/extract/raw_data_part_2.csv', low_memory=False)

# %%
# Function to confirm null percentages in each column of a dataframe
def null_percentages(df):
    nulls = df.isnull().sum()
    total = len(df)
    percent_null = (nulls / total) * 100
    return percent_null

# %%
forces_df.head()
# Out:
#                   id                            name
# 0  avon-and-somerset  Avon and Somerset Constabulary
# 1       bedfordshire             Bedfordshire Police
# 2     cambridgeshire     Cambridgeshire Constabulary
# 3           cheshire           Cheshire Constabulary
# 4     city-of-london           City of London Police

# %%
dates_df.head()
# Out:
#       date                                    stop-and-search
# 0  2025-08  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 1  2025-07  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 2  2025-06  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 3  2025-05  ['avon-and-somerset', 'bedfordshire', 'btp', '...
# 4  2025-04  ['avon-and-somerset', 'bedfordshire', 'btp', '...

# %%
crime_data_df.head()
# Out:
#             force_id age_range                       outcome  involved_person  \
# 0  avon-and-somerset     25-34                        Arrest             True
# 1  avon-and-somerset     18-24                        Arrest             True
# 2  avon-and-somerset     25-34          Community resolution             True
# 3  avon-and-somerset     25-34  A no further action disposal             True
# 4  avon-and-somerset       NaN  A no further action disposal             True
#
#                               self_defined_ethnicity gender  \
# 0  White - English/Welsh/Scottish/Northern Irish/...   Male
# 1  Mixed/Multiple ethnic groups - Any other Mixed...   Male
# 2                 White - Any other White background    NaN
# 3    Black/African/Caribbean/Black British - African   Male
# 4                                                NaN   Male
#
#                                          legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3              Misuse of Drugs Act 1971 (section 23)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#   outcome_linked_to_object_of_search                   datetime  \
# 0                               True  2025-08-15T12:28:49+00:00
# 1                               True  2025-08-11T11:34:38+00:00
# 2                                NaN  2025-08-10T21:28:27+00:00
# 3                              False  2025-08-19T17:32:44+00:00
# 4                                NaN  2025-08-29T09:14:43+00:00
#
#   removal_of_more_than_outer_clothing  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#                                       outcome_object  \
# 0              {'id': 'bu-arrest', 'name': 'Arrest'}
# 1              {'id': 'bu-arrest', 'name': 'Arrest'}
# 2  {'id': 'bu-community-resolution', 'name': 'Com...
# 3  {'id': 'bu-no-further-action', 'name': 'A no f...
# 4  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                             location operation  \
# 0  {'latitude': '51.436433', 'street': {'id': 227...       NaN
# 1                                                NaN       NaN
# 2  {'latitude': '51.350126', 'street': {'id': 226...       NaN
# 3  {'latitude': '50.955387', 'street': {'id': 227...       NaN
# 4  {'latitude': '50.940540', 'street': {'id': 227...       NaN
#
#   officer_defined_ethnicity                       type  operation_name  \
# 0                     White              Person search             NaN
# 1                     White  Person and Vehicle search             NaN
# 2                     White              Person search             NaN
# 3                     Black              Person search             NaN
# 4                       NaN              Person search             NaN
#
#     object_of_search
# 0   Controlled drugs
# 1   Controlled drugs
# 2   Controlled drugs
# 3   Controlled drugs
# 4  Offensive weapons

# %% [markdown]
# Columns outcome_object and location contain dictionaries
# Solution:
# - outcome_object: replace with values of 'name' key
#   - Outcome already recorded elsewhere - Drop column
# - location: new columns with values of 'latitude' and 'longitude' keys, drop location column

# %%
# Working code to extract 'latitude' and 'longitude' from 'location' column and store as new columns
crime_data_df = crime_data_df.assign(
    latitude=crime_data_df['location'].apply(lambda x: eval(x)['latitude'] if pd.notnull(x) else x),
    longitude=crime_data_df['location'].apply(lambda x: eval(x)['longitude'] if pd.notnull(x) else x)
)
crime_data_df.head()
# Out:
#             force_id age_range                       outcome  involved_person  \
# 0  avon-and-somerset     25-34                        Arrest             True
# 1  avon-and-somerset     18-24                        Arrest             True
# 2  avon-and-somerset     25-34          Community resolution             True
# 3  avon-and-somerset     25-34  A no further action disposal             True
# 4  avon-and-somerset       NaN  A no further action disposal             True
#
#                               self_defined_ethnicity gender  \
# 0  White - English/Welsh/Scottish/Northern Irish/...   Male
# 1  Mixed/Multiple ethnic groups - Any other Mixed...   Male
# 2                 White - Any other White background    NaN
# 3    Black/African/Caribbean/Black British - African   Male
# 4                                                NaN   Male
#
#                                          legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3              Misuse of Drugs Act 1971 (section 23)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#   outcome_linked_to_object_of_search                   datetime  \
# 0                               True  2025-08-15T12:28:49+00:00
# 1                               True  2025-08-11T11:34:38+00:00
# 2                                NaN  2025-08-10T21:28:27+00:00
# 3                              False  2025-08-19T17:32:44+00:00
# 4                                NaN  2025-08-29T09:14:43+00:00
#
#   removal_of_more_than_outer_clothing  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#                                       outcome_object  \
# 0              {'id': 'bu-arrest', 'name': 'Arrest'}
# 1              {'id': 'bu-arrest', 'name': 'Arrest'}
# 2  {'id': 'bu-community-resolution', 'name': 'Com...
# 3  {'id': 'bu-no-further-action', 'name': 'A no f...
# 4  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                             location operation  \
# 0  {'latitude': '51.436433', 'street': {'id': 227...       NaN
# 1                                                NaN       NaN
# 2  {'latitude': '51.350126', 'street': {'id': 226...       NaN
# 3  {'latitude': '50.955387', 'street': {'id': 227...       NaN
# 4  {'latitude': '50.940540', 'street': {'id': 227...       NaN
#
#   officer_defined_ethnicity                       type  operation_name  \
# 0                     White              Person search             NaN
# 1                     White  Person and Vehicle search             NaN
# 2                     White              Person search             NaN
# 3                     Black              Person search             NaN
# 4                       NaN              Person search             NaN
#
#     object_of_search   latitude  longitude
# 0   Controlled drugs  51.436433  -2.589311
# 1   Controlled drugs        NaN        NaN
# 2   Controlled drugs  51.350126  -2.976136
# 3   Controlled drugs  50.955387  -2.642046
# 4  Offensive weapons  50.940540  -2.633928

# %%
# Merge forces and crime data dataframes on 'force_id' column
forces_df = forces_df.rename(columns={'id': 'force_id'})
forces_df['force_id'] = forces_df['force_id'].astype(str)
crime_data_df['force_id'] = crime_data_df['force_id'].astype(str)
crime_data_df = crime_data_df.merge(forces_df, on='force_id', how='left')
crime_data_df.head()
# Out:
#             force_id age_range                       outcome  involved_person  \
# 0  avon-and-somerset     25-34                        Arrest             True
# 1  avon-and-somerset     18-24                        Arrest             True
# 2  avon-and-somerset     25-34          Community resolution             True
# 3  avon-and-somerset     25-34  A no further action disposal             True
# 4  avon-and-somerset       NaN  A no further action disposal             True
#
#                               self_defined_ethnicity gender  \
# 0  White - English/Welsh/Scottish/Northern Irish/...   Male
# 1  Mixed/Multiple ethnic groups - Any other Mixed...   Male
# 2                 White - Any other White background    NaN
# 3    Black/African/Caribbean/Black British - African   Male
# 4                                                NaN   Male
#
#                                          legislation  \
# 0              Misuse of Drugs Act 1971 (section 23)
# 1              Misuse of Drugs Act 1971 (section 23)
# 2              Misuse of Drugs Act 1971 (section 23)
# 3              Misuse of Drugs Act 1971 (section 23)
# 4  Police and Criminal Evidence Act 1984 (section 1)
#
#   outcome_linked_to_object_of_search                   datetime  \
# 0                               True  2025-08-15T12:28:49+00:00
# 1                               True  2025-08-11T11:34:38+00:00
# 2                                NaN  2025-08-10T21:28:27+00:00
# 3                              False  2025-08-19T17:32:44+00:00
# 4                                NaN  2025-08-29T09:14:43+00:00
#
#   removal_of_more_than_outer_clothing  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#                                       outcome_object  \
# 0              {'id': 'bu-arrest', 'name': 'Arrest'}
# 1              {'id': 'bu-arrest', 'name': 'Arrest'}
# 2  {'id': 'bu-community-resolution', 'name': 'Com...
# 3  {'id': 'bu-no-further-action', 'name': 'A no f...
# 4  {'id': 'bu-no-further-action', 'name': 'A no f...
#
#                                             location operation  \
# 0  {'latitude': '51.436433', 'street': {'id': 227...       NaN
# 1                                                NaN       NaN
# 2  {'latitude': '51.350126', 'street': {'id': 226...       NaN
# 3  {'latitude': '50.955387', 'street': {'id': 227...       NaN
# 4  {'latitude': '50.940540', 'street': {'id': 227...       NaN
#
#   officer_defined_ethnicity                       type  operation_name  \
# 0                     White              Person search             NaN
# 1                     White  Person and Vehicle search             NaN
# 2                     White              Person search             NaN
# 3                     Black              Person search             NaN
# 4                       NaN              Person search             NaN
#
#     object_of_search   latitude  longitude                            name
# 0   Controlled drugs  51.436433  -2.589311  Avon and Somerset Constabulary
# 1   Controlled drugs        NaN        NaN  Avon and Somerset Constabulary
# 2   Controlled drugs  51.350126  -2.976136  Avon and Somerset Constabulary
# 3   Controlled drugs  50.955387  -2.642046  Avon and Somerset Constabulary
# 4  Offensive weapons  50.940540  -2.633928  Avon and Somerset Constabulary

# %%
# Identify columns to drop
columns_to_drop = [
    'outcome_object', # Outcome already recorded elsewhere
    'location',       # Latitude and Longitude extracted
    'force_id',       # Police force identifier replaced by 'force_name'
    'operation',      # Unused column
    'operation_name',  # Unused column
    
]

# Drop specified columns
crime_data_df = crime_data_df.drop(columns=columns_to_drop)
crime_data_df.head()
